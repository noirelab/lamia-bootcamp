# %% [markdown]
# # Google Colab notebook

# %% [markdown]
# isso funciona!

# %%
print('hello viewers')
# Out:
# hello viewers

# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib

# %%
# dados pra plot
data = np.arange(0.0, 2.0, 0.01)
data2 = 1 + np.sin(2*np.pi*data)

fig, ax = plt.subplots()
ax.plot(data, data2)
ax.grid()
