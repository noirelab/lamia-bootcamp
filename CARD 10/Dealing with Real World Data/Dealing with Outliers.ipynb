# %%
# %matplotlib inline
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
incomes = np.append(incomes, [1000000000])

import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %%
incomes.mean()
# Out:
# 126963.52928743674

# %%
def reject_ouliers(data):
    u = np.median(data)
    s = np.std(data)
    
    # e é aceito caso for um valor dentro do intervalo
    filtered = [e for e in data if (u - 2 * s < e < u + 2 * s)]
    return filtered

filtered = reject_ouliers(incomes)

plt.hist(filtered, 50)
plt.show()

# %%
np.mean(filtered)
# Out:
# 26976.225640365457
